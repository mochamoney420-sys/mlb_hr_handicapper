# %% [markdown]
# # MLB Home Run Handicapping Pipeline
# Run this notebook to pull fresh data, sync to GitHub, and broadcast predictions.

# %%
# 1. Install dependencies on the Colab server
# %pip install pandas numpy xgboost requests pybaseball
# Out:
# Requirement already satisfied: pandas in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.5.0)
# Requirement already satisfied: xgboost in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.3.0)
# Requirement already satisfied: requests in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.34.2)
# Requirement already satisfied: pybaseball in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.2.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: scipy in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from xgboost) (1.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests) (2026.6.17)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (4.15.0)
# Requirement already satisfied: lxml>=4.2.1 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (6.1.1)
# Requirement already satisfied: pyarrow>=1.0.1 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (24.0.0)
# Requirement already satisfied: pygithub>=1.51 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (2.9.1)
# Requirement already satisfied: matplotlib>=2.0.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (3.11.0)
# Requirement already satisfied: tqdm>=4.50.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (4.68.3)
# Requirement already satisfied: attrs>=20.3.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pybaseball) (26.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=2.0.0->pybaseball) (3.3.2)
# Requirement already satisfied: pynacl>=1.4.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pygithub>=1.51->pybaseball) (1.6.2)
# Requirement already satisfied: pyjwt>=2.4.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.13.0)
# Requirement already satisfied: cryptography>=3.4.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (3.0)
# Requirement already satisfied: six>=1.5 in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\bobby\AppData\Local\Programs\Python\Python314\Lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)

# %%
# 2. Run the handicapping prediction pipeline
import os
# Paste your Discord URL directly here for manual Colab runs
os.environ['DISCORD_WEBHOOK_URL'] = 'https://discord.com/api/webhooks/1525525618861543654/jBzZ7vTarJs-j2apC7Ws2M29cF5aaJ9-0JkvdyyK9aJUJRziU9MXqfHyzx0roW4HVHIZ'

# !python run_daily_predictions.py
